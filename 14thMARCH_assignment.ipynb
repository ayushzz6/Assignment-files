# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushzz6/Assignment-files/blob/main/14thMARCH_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.0)

# %%
df= pd.read_csv('heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
#QUESTION NO 1
#  What is the distribution of age among heart failure patients in the dataset

# %%
df['age'].value_counts().plot.pie(y= df['age'] , autopct= '%.1f'  , figsize = (12,12))
# Out:
# <Axes: ylabel='age'>

# %%
# QUESTION NO 2
# How does the death rate vary with age

# %%
df.plot( y ='DEATH_EVENT' , x ='age')
# Out:
# <Axes: xlabel='age'>

# %%
#QUESTION NO 3
# What is the percentage of male and female patients in the dataset?

# %%
df.sex.value_counts()
# Out:
# 1    194
# 0    105
# Name: sex, dtype: int64

# %%
#QUESTION NO 4
#How does the platelet count vary among different age groups

# %%
df.plot.scatter( y ='platelets' , x ='age')
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
#QUESTION NO 5
# Is there a correlation between creatinine and sodium levels in the blood

# %%
df1= df[['serum_creatinine','serum_sodium']]
df1.corr()
sns.heatmap(df1.corr() , annot = True )
# Out:
# <Axes: >

# %%
#QUESTION NO 6
# How does the prevalence of high blood pressure differ between male and female patients

# %%
sns.countplot(x='sex',hue='high_blood_pressure',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#QUESTION NO 7
# What is the relationship between smoking habits and the occurrence of heart failure

# %%
sns.barplot(x ='DEATH_EVENT' , y = 'smoking' ,  data = df)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='smoking'>

# %%
#QUESTION NO 8
# Are there any noticeable patterns in the distribution of death events across different age groups

# %%
sns.set(rc={"figure.figsize":(25, 25)})
sns.barplot(data = df , x= 'age', y = 'DEATH_EVENT' )
# Out:
# <Axes: xlabel='age', ylabel='DEATH_EVENT'>

# %%
#QUESTION NO 9
# Is there any significant difference in ejection fraction between patients with and without diabetes

# %%
sns.boxplot(data = df , x=  'diabetes' , y ='ejection_fraction')
# Out:
# <Axes: xlabel='diabetes', ylabel='ejection_fraction'>

# %%
#QUESTION NO 10
# How does the serum creatinine level vary between patients who survived and those who did not?

# %%
sns.countplot(x='DEATH_EVENT' , hue='serum_creatinine' , data = df)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>
