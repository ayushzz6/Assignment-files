# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushzz6/Assignment-files/blob/main/EDA_PLAYSTORE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.sample(6)
# Out:
#                                 App Category  Rating Reviews  \
# 8624                 Darkness Rises   FAMILY     4.7  456474
# 5604              PS4 Second Screen   FAMILY     2.4   11773
# 9628                         Edmodo   FAMILY     4.1  200214
# 4294            K-Chiing VPN (Free)    TOOLS     3.7      43
# 9620   Hello English: Learn English   FAMILY     4.6  750321
# 10368                     FG Finder    TOOLS     NaN     154
#
#                      Size     Installs  Type Price Content Rating  \
# 8624                  86M   5,000,000+  Free     0           Teen
# 5604                 3.3M   1,000,000+  Free     0       Everyone
# 9628                  18M  10,000,000+  Free     0       Everyone
# 4294                  10M       5,000+  Free     0     Mature 17+
# 9620   Varies with device  10,000,000+  Free     0       Everyone
# 10368                 17M      10,000+  Free     0       Everyone
#
# ...

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Rating'].plot(kind='line', figsize=(8, 4), title='Rating')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.describe(include = 'all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.drop_duplicates(inplace= True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.drop([10472] , inplace  = True )

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
type('Reviews')
# Out:
# str

# %%
df['Reviews'].astype(int)
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10357, dtype: int64

# %%
df['Reviews'].dtypes
# Out:
# dtype('O')

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
sns.histplot(df['Reviews'])
# Out:
# <Axes: xlabel='Reviews', ylabel='Count'>

# %%
df['Size'] = df['Size'].str.replace('M' , '000')

# %%
df['Size']
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10836                 53000
# 10837                3.6000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10357, dtype: object

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10357, dtype: object

# %%
cf = [feature for feature in df.columns if df[feature].dtype =='O']
cf
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
nf = [feature for feature in df.columns if df[feature].dtype !='O']
nf
# Out:
# ['Rating']

# %%
a=df['Type'].value_counts()

# %%
sns.countplot(x= df['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.distplot(df['Rating'])
# Out:
# <ipython-input-70-1beb45e76234>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rating'])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df['Category'].value_counts().plot.pie(y = df['Category'], autopct = '%1.1f',figsize =(12,12))
# Out:
# <Axes: ylabel='Category'>

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
# Out:
#                Category                                           Installs
# 0          PRODUCTIVITY  500,000,000+10,000,000+100,000,000+10,000,000+...
# 1                BEAUTY  500,000+1,000,000+100,000+500,000+1,000,000+50...
# 2                FAMILY  50,000,000+10,000,000+100,000,000+1,000,000+5,...
# 3               WEATHER  50,000,000+1,000,000+50,000,000+10,000+10,000,...
# 4       PERSONALIZATION  50,000,000+1,000,000+100,000,000+5,000,000+100...
# 5    LIBRARIES_AND_DEMO  50,000+10,000+100,000+1,000+100,000+10,000+100...
# 6             LIFESTYLE  5,000,000+10,000,000+100,000+10,000,000+5,000,...
# 7   BOOKS_AND_REFERENCE  100,000,000+50,000+100,000+10,000,000+100,000,...
# 8   MAPS_AND_NAVIGATION  100,000,000+5,000,000+10,000,000+10,000,000+5,...
# 9             EDUCATION  100,000,000+10,000,000+100,000+5,000,000+10,00...
# 10                 GAME  100,000,000+1,000,000,000+500,000,000+10,000,0...
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
a1 = df.groupby(['Category', 'Type'])['Installs'].sum().sort_values(ascending = True)
a1
# Out:
# Category         Type
# EVENTS           Paid                                                   1+
# EDUCATION        Paid                         1,000+1,000+500,000+100,000+
# SOCIAL           Paid                                       1,000+5,000+0+
# MEDICAL          Free    1,000,000+1,000,000+1,000,000+1,000,000+1,000,...
# PERSONALIZATION  Paid    1,000,000+1,000,000+10,000+10,000+100,000+100+...
#                                                ...
#                  Free    50,000,000+1,000,000+100,000,000+5,000,000+100...
# WEATHER          Free    50,000,000+1,000,000+50,000,000+10,000+10,000,...
# FAMILY           Free    50,000,000+10,000,000+100,000,000+1,000,000+5,...
# BEAUTY           Free    500,000+1,000,000+100,000+500,000+1,000,000+50...
# PRODUCTIVITY     Free    500,000,000+10,000,000+100,000,000+10,000,000+...
# Name: Installs, Length: 63, dtype: object

# %%
a1[a1.Category == 'GAME']
# Out:
#    Category  Type                                           Installs
# 38     GAME  Paid  100,000+100,000+100,000+100,000+100,000+100,00...
# 43     GAME  Free  100,000,000+1,000,000,000+500,000,000+10,000,0...
