# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushzz6/Assignment-files/blob/main/EDA_US_VISA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import seaborn as sns

# %%
df= pd.read_csv('us_perm_visas.csv')
df
# Out:
# <ipython-input-4-791f7b488f87>:1: DtypeWarning:
#
# Columns (79) have mixed types. Specify dtype option on import or set low_memory=False.
#       add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                             NaN         NaN              NaN          NaN
# 1                             NaN         NaN              NaN          NaN
# 2                             NaN         NaN              NaN          NaN
# 3                             NaN         NaN              NaN          NaN
# 4                             NaN         NaN              NaN          NaN
# ...                           ...         ...              ...          ...
# 4814                          NaN         NaN              NaN          NaN
# 4815                          NaN         NaN              NaN          NaN
# 4816                          NaN         NaN              NaN          NaN
# ...

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df1 = df[df['case_status'] != 'Withdrawn']
df1
# Out:
#      application_type        case_no case_status class_of_admission  \
# 0                PERM  A-07323-97014   Certified                J-1
# 1                PERM  A-07332-99439      Denied                B-2
# 2                PERM  A-07333-99643   Certified               H-1B
# 3                PERM  A-07339-01930   Certified                B-2
# 4                PERM  A-07345-03565   Certified                L-1
# ...               ...            ...         ...                ...
# 4814             PERM  A-11166-85701   Certified               H-1B
# 4815             PERM  A-11166-85705      Denied               H-1B
# 4816             PERM  A-11166-85707   Certified                NaN
# 4817             PERM  A-11166-85712      Denied               H-1B
# 4818             PERM  A-11166-85719   Certified               H-1B
#
#      country_of_citzenship decision_date               employer_address_1  \
# 0                  ARMENIA    2012-02-01                24 WEST 25 STREET
# ...

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Withdrawn'], dtype=object)

# %%
df['case_status'] = df['case_status'].str.replace('Certified-Expired','Certified')

# %%
df.case_status.value_counts(normalize = True)
# Out:
# Certified    0.677319
# Denied       0.278689
# Withdrawn    0.043993
# Name: case_status, dtype: float64

# %%
df.dropna(axis = 1 , how = 'all', inplace = True)

# %%
df.application_type
# Out:
# 0       PERM
# 1       PERM
# 2       PERM
# 3       PERM
# 4       PERM
#         ...
# 4814    PERM
# 4815    PERM
# 4816    PERM
# 4817    PERM
# 4818    PERM
# Name: application_type, Length: 4819, dtype: object

# %%
sns.countplot(x = 'us_economic_sector' , data = df  )
# Out:
# <Axes: xlabel='us_economic_sector', ylabel='count'>

# %%
a = df['us_economic_sector'].value_counts()
a
# Out:
# IT                       1522
# Other Economic Sector     746
# Advanced Mfg              641
# Educational Services      429
# Hospitality               289
# Finance                   242
# Health Care               240
# Retail                    190
# Construction              151
# Aerospace                 102
# Automotive                 49
# Transportation             37
# Agribusiness               34
# Energy                     24
# Biotechnology               7
# Homeland Security           3
# Geospatial                  2
# Name: us_economic_sector, dtype: int64

# %%
plt.pie(a  , labels = a.index,autopct ='%1.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x793da0390a90>,
# ...
#  [Text(0.5798093886980928, 0.9347839711813334, 'IT'),
#   Text(-0.8999900485877196, 0.632469692904786, 'Other Economic Sector'),
#   Text(-1.0465696610874453, -0.3386619915067384, 'Advanced Mfg'),
#   Text(-0.5691681155516779, -0.9413010444269952, 'Educational Services'),
#   Text(-0.07114981180890413, -1.09769654471514, 'Hospitality'),
#   Text(0.3141291389421316, -1.0541930013367928, 'Finance'),
#   Text(0.6312681696128244, -0.9008332243171733, 'Health Care'),
#   Text(0.860406833991107, -0.6853466860074542, 'Retail'),
#   Text(0.9928333280603044, -0.47358418754504467, 'Construction'),
#   Text(1.058291353620415, -0.3000323496762803, 'Aerospace'),
#   Text(1.0831039345549272, -0.1920569367443831, 'Automotive'),
#   Text(1.0923364430916438, -0.1296190383157365, 'Transportation'),
#   Text(1.0972494538700832, -0.07774082570827422, 'Agribusiness'),
#   Text(1.099435801214304, -0.03522668034689004, 'Energy'),
# ...

# %%
df['decision_date']
# Out:
# 0       2012-02-01
# 1       2011-12-21
# 2       2011-12-01
# 3       2011-12-01
# 4       2012-01-26
#            ...
# 4814    2012-01-30
# 4815    2012-02-07
# 4816    2012-02-10
# 4817    2011-12-27
# 4818    2011-10-06
# Name: decision_date, Length: 4819, dtype: object
